# %% [markdown]
# # Week 0: Raspberry Pi Jupyter Setup
#
# This notebook is used to verify that the Raspberry Pi Jupyter environment is working correctly.
#
# It also contains:
# - a simple execution test on the Raspberry Pi
# - the Section 4.1.3 code block
# - a safe shutdown block for the Raspberry Pi

# %% [markdown]
# ## 1. Environment Check
#
# The following cells confirm that this notebook is running on the Raspberry Pi and using the correct virtual environment.

# %% [markdown]
# ## 2. Section 4.1.3 Execution
#
# This section contains the code from Section 4.1.3.
# When this code is run here, it executes on the Raspberry Pi through the active Jupyter kernel.

# %%
import sys
print(sys.executable)
# Out:
# /home/pi/cw_jupyter/.venv/bin/python

# %%
import os
print(os.getcwd())
# Out:
# /home/pi/cw_jupyter

# %%
from gpiozero import LED
print("gpiozero import successful")
# Out:
# gpiozero import successful

# %% [markdown]
# ## 3. Safe Shutdown
#
# Run the next code cell only when you are completely finished working on the Raspberry Pi.
# This will safely shut down the Raspberry Pi operating system.

# %%
import os
print("Shutting down Raspberry Pi safely...")
os.system("sudo shutdown -h now")
# Out:
# Shutting down Raspberry Pi safely...
